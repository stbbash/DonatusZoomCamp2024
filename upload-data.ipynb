# %%
import pandas as pd

# %%
df = pd.read_csv("yellow_tripdata_2021-07.csv", nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-07-01 00:08:51   2021-07-01 00:13:05                1
# 1          1  2021-07-01 00:22:39   2021-07-01 00:25:58                1
# 2          1  2021-07-01 00:48:33   2021-07-01 00:54:58                1
# 3          1  2021-07-01 00:59:44   2021-07-01 01:07:09                1
# 4          1  2021-07-01 00:08:35   2021-07-01 00:16:28                0
# ..       ...                  ...                   ...              ...
# 95         1  2021-07-01 00:35:21   2021-07-01 00:40:49                1
# 96         2  2021-07-01 00:04:34   2021-07-01 00:20:15                2
# 97         2  2021-07-01 00:29:29   2021-07-01 00:36:14                3
# 98         1  2021-07-01 00:12:37   2021-07-01 00:22:54                1
# 99         1  2021-07-01 00:27:11   2021-07-01 00:35:23                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.80           1                  N            90            68
# 1            0.90           1                  N           113            90
# 2            2.80           1                  N            88           232
# 3            1.40           1                  N            79           249
# 4            2.00           1                  N           142           238
# ..            ...         ...                ...           ...           ...
# 95           1.40           1                  N           249            68
# 96           3.11           1                  N            48             4
# 97           2.84           1                  N            79           140
# 98           2.00           1                  N            41           116
# 99           2.00           1                  N           116           151
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1          5.0    3.0      0.5        0.00           0.0
# 1              2          5.0    3.0      0.5        0.00           0.0
# 2              2         10.0    3.0      0.5        0.00           0.0
# 3              1          7.0    3.0      0.5        1.50           0.0
# 4              1          8.5    3.0      0.5        0.00           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1          6.5    3.0      0.5        2.55           0.0
# 96             1         13.5    0.5      0.5        3.46           0.0
# 97             1          9.5    0.5      0.5        3.32           0.0
# 98             2          9.5    0.5      0.5        0.00           0.0
# 99             1          9.0    0.5      0.5        4.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3          8.80                   2.5
# 1                     0.3          8.80                   2.5
# 2                     0.3         13.80                   2.5
# 3                     0.3         12.30                   2.5
# 4                     0.3         12.30                   2.5
# ..                    ...           ...                   ...
# 95                    0.3         12.85                   2.5
# 96                    0.3         20.76                   2.5
# 97                    0.3         16.62                   2.5
# 98                    0.3         10.80                   0.0
# 99                    0.3         14.30                   0.0
#
# [100 rows x 18 columns]

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost/ny_taxi")

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv("yellow_tripdata_2021-07.csv", iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-07-01 00:08:51   2021-07-01 00:13:05                1
# 1             1  2021-07-01 00:22:39   2021-07-01 00:25:58                1
# 2             1  2021-07-01 00:48:33   2021-07-01 00:54:58                1
# 3             1  2021-07-01 00:59:44   2021-07-01 01:07:09                1
# 4             1  2021-07-01 00:08:35   2021-07-01 00:16:28                0
# ...         ...                  ...                   ...              ...
# 99995         1  2021-07-02 08:48:33   2021-07-02 09:04:45                0
# 99996         1  2021-07-02 08:33:48   2021-07-02 08:39:06                1
# 99997         1  2021-07-02 08:41:40   2021-07-02 08:48:48                1
# 99998         1  2021-07-02 08:53:00   2021-07-02 09:01:30                1
# 99999         2  2021-07-02 08:21:00   2021-07-02 08:25:00                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               0.80           1                  N            90
# 1               0.90           1                  N           113
# 2               2.80           1                  N            88
# 3               1.40           1                  N            79
# 4               2.00           1                  N           142
# ...              ...         ...                ...           ...
# 99995           5.10           1                  N           141
# 99996           1.10           1                  N           107
# 99997           1.40           1                  N           170
# 99998           1.50           1                  N           229
# 99999           0.74           1                  N           237
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                68             1          5.0    3.0      0.5        0.00
# 1                90             2          5.0    3.0      0.5        0.00
# 2               232             2         10.0    3.0      0.5        0.00
# 3               249             1          7.0    3.0      0.5        1.50
# 4               238             1          8.5    3.0      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 99995             4             1         16.5    3.0      0.5        5.00
# 99996           170             1          6.0    2.5      0.5        7.00
# 99997           141             2          7.0    2.5      0.5        0.00
# 99998           263             1          8.0    2.5      0.5        2.00
# 99999           262             1          5.0    0.0      0.5        1.66
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0               0.0                    0.3          8.80                   2.5
# 1               0.0                    0.3          8.80                   2.5
# 2               0.0                    0.3         13.80                   2.5
# 3               0.0                    0.3         12.30                   2.5
# 4               0.0                    0.3         12.30                   2.5
# ...             ...                    ...           ...                   ...
# 99995           0.0                    0.3         25.30                   2.5
# 99996           0.0                    0.3         16.30                   2.5
# 99997           0.0                    0.3         10.30                   2.5
# 99998           0.0                    0.3         13.30                   2.5
# 99999           0.0                    0.3          9.96                   2.5
#
# [100000 rows x 18 columns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(n=0).to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
# %time df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
# Out:
# CPU times: user 6.78 s, sys: 123 ms, total: 6.9 s
# Wall time: 9.95 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")

    t_end = time()
    #print(f"inserted another chunck..., took {t_end - t_start}")
    print("inserted another chunck..., took %.3f seconds" % (t_end - t_start))
# Out:
# inserted another chunck..., took 9.534 seconds
# inserted another chunck..., took 9.134 seconds
# inserted another chunck..., took 9.480 seconds
# inserted another chunck..., took 9.927 seconds
# inserted another chunck..., took 9.333 seconds
# inserted another chunck..., took 9.604 seconds
# inserted another chunck..., took 9.532 seconds
# inserted another chunck..., took 9.458 seconds
# inserted another chunck..., took 9.422 seconds
# inserted another chunck..., took 9.608 seconds
# inserted another chunck..., took 9.415 seconds
# inserted another chunck..., took 9.367 seconds
# inserted another chunck..., took 9.213 seconds
# inserted another chunck..., took 9.689 seconds
# inserted another chunck..., took 9.480 seconds
# inserted another chunck..., took 9.474 seconds
# inserted another chunck..., took 9.687 seconds
# inserted another chunck..., took 9.411 seconds
# inserted another chunck..., took 9.237 seconds
# inserted another chunck..., took 9.534 seconds
# inserted another chunck..., took 9.112 seconds
# inserted another chunck..., took 10.075 seconds
# inserted another chunck..., took 9.677 seconds
# inserted another chunck..., took 9.134 seconds
# inserted another chunck..., took 9.354 seconds
# /tmp/ipykernel_45287/3378363201.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunck..., took 9.632 seconds
# inserted another chunck..., took 8.388 seconds
# inserted another chunck..., took 1.907 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[37], line 3
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       5     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       6     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1841, in TextFileReader.__next__(self)
#    1839 def __next__(self) -> DataFrame:
#    1840     try:
# -> 1841         return self.get_chunk()
#    1842     except StopIteration:
#    1843         self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1983, in TextFileReader.get_chunk(self, size)
#    1981         raise StopIteration
#    1982     size = min(size, self.nrows - self._currow)
# -> 1983 return self.read(nrows=size)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1921, in TextFileReader.read(self, nrows)
#    1914 nrows = validate_integer("nrows", nrows)
#    1915 try:
#    1916     # error: "ParserBase" has no attribute "read"
#    1917     (
#    1918         index,
#    1919         columns,
#    1920         col_dict,
# -> 1921     ) = self._engine.read(  # type: ignore[attr-defined]
#    1922         nrows
#    1923     )
#    1924 except Exception:
#    1925     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:863, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
